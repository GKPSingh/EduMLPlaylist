# %%
# Importing required libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from math import log

# %%
# Loading the data
df= pd.read_csv('cereal.csv')

# %%
# Checking the data
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
len(df['name'].value_counts())
# Out:
# 77

# %%
# Checking number of rows and columns in the data
df.shape
# Out:
# (77, 16)

# %% [markdown]
# ### Question 1. Load the data from “cereal.csv” and plot histograms of sugar and vitamin content across different cereals.[Hint: Extract values of a specific column using their labels and use hist method of pyplot]

# %%
# plotting the hist plot
plt.hist([df["sugars"], df["vitamins"]],
         color=['orange', 'green'])
plt.title("Sugars and Vitamins")
plt.xlabel("Sugars and Vitamins")
plt.legend(["Sugars", " Vitamins"])
plt.show()

# %% [markdown]
# ### Question 2:  The names of the manufactures are coded using alphabets, create a new column with their fullname using the below mapping.

# %%
dict_mfr = {'N': 'Nabisco',
            'Q': 'Quaker Oats',
            'K': 'Kelloggs',
            'R': 'Raslston Purina',
            'G': 'General Mills',
            'P': 'Post',
            'A': 'American Home Foods Products'}

df["manufactures"] = [dict_mfr[mfr] for mfr in df["mfr"]]

# %% [markdown]
# ### Question 2: Create a bar plot where each manufacturer is on the y axis and the height of the bars depict the number of cereals manufactured by them.[Hint: Try using countplot this time or bar method of pyplot]

# %%
df['manufactures'].value_counts().plot(kind='bar');

# %%
# Making Label Encoding of name column
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['name']= le.fit_transform(df['name'])

# %%
# Checking the data 
df.head(50)
# Out:
#     name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 0      0   N    C        70        4    1     130   10.0    5.0       6
# 1      1   Q    C       120        3    5      15    2.0    8.0       8
# 2      2   K    C        70        4    1     260    9.0    7.0       5
# 3      3   K    C        50        4    0     140   14.0    8.0       0
# 4      4   R    C       110        2    2     200    1.0   14.0       8
# 5      5   G    C       110        2    2     180    1.5   10.5      10
# 6      6   K    C       110        2    0     125    1.0   11.0      14
# 7      7   G    C       130        3    2     210    2.0   18.0       8
# 8      8   R    C        90        2    1     200    4.0   15.0       6
# 9      9   P    C        90        3    0     210    5.0   13.0       5
# 10    10   Q    C       120        1    2     220    0.0   12.0      12
# 11    11   G    C       110        6    2     290    2.0   17.0       1
# ...

# %%
# Generating Label encoding for manufactures column
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['manufactures']=le.fit_transform(df['manufactures'])

# %%
# Generating dummy variables for type column
type_dumm = pd.get_dummies(df['type'])
type_dumm
# Out:
#     C  H
# 0   1  0
# 1   1  0
# 2   1  0
# 3   1  0
# 4   1  0
# .. .. ..
# 72  1  0
# 73  1  0
# 74  1  0
# 75  1  0
# 76  1  0
#
# [77 rows x 2 columns]

# %%
# Concating the data
df = pd.concat([df,type_dumm], axis=1)

# %%
# Dropping the columns
df.drop(['mfr','H','type'], axis=1, inplace=True)

# %%
# Checking the data
df.head()
# Out:
#    name  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0     0        70        4    1     130   10.0    5.0       6     280
# 1     1       120        3    5      15    2.0    8.0       8     135
# 2     2        70        4    1     260    9.0    7.0       5     320
# 3     3        50        4    0     140   14.0    8.0       0     330
# 4     4       110        2    2     200    1.0   14.0       8      -1
#
#    vitamins  shelf  weight  cups     rating  manufactures  C
# 0        25      3     1.0  0.33  68.402973             3  1
# 1         0      3     1.0  1.00  33.983679             5  1
# 2        25      3     1.0  0.33  59.425505             2  1
# 3        25      3     1.0  0.50  93.704912             2  1
# 4        25      3     1.0  0.75  34.384843             6  1

# %%
# Plotting the histogram plot for all numeric and boolean columns
df.hist(figsize = (20, 20), bins = 10)
plt.tight_layout()

# %%
# Scaling the calories columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[['calories']])
df['calories']=scaler.transform(df[['calories']])

# %%
scaler.fit(df[['protein']])
df['protein']=scaler.transform(df[['protein']])

# %%
#Scaling the fat columns
scaler.fit(df[['fat']])
df['fat']=scaler.transform(df[['fat']])

# %%
# Scaling the sodium columns
scaler.fit(df[['sodium']])
df['sodium']=scaler.transform(df[['sodium']])

# %%
#Scaling the fiber columns
scaler.fit(df[['fiber']])
df['fiber']=scaler.transform(df[['fiber']])

# %%
# Scaling the carbo columns
scaler.fit(df[['carbo']])
df['carbo']=scaler.transform(df[['carbo']])

# %%
#Scaling the sugars column
scaler.fit(df[['sugars']])
df['sugars']=scaler.transform(df[['sugars']])

# %%
# Scaling the potass columns
scaler.fit(df[['potass']])
df['potass']=scaler.transform(df[['potass']])

# %%
# Scaling the vitamins column
scaler.fit(df[['vitamins']])
df['vitamins']=scaler.transform(df[['vitamins']])

# %%
# Scaling the cups column
scaler.fit(df[['cups']])
df['cups']=scaler.transform(df[['cups']])

# %%
# Checking the data
df.head()
# Out:
#    name  calories  protein  fat    sodium     fiber     carbo  sugars  \
# 0     0  0.181818      0.6  0.2  0.406250  0.714286  0.250000  0.4375
# 1     1  0.636364      0.4  1.0  0.046875  0.142857  0.375000  0.5625
# 2     2  0.181818      0.6  0.2  0.812500  0.642857  0.333333  0.3750
# 3     3  0.000000      0.6  0.0  0.437500  1.000000  0.375000  0.0625
# 4     4  0.545455      0.2  0.4  0.625000  0.071429  0.625000  0.5625
#
#      potass  vitamins  shelf  weight   cups     rating  manufactures  C
# 0  0.848943      0.25      3     1.0  0.064  68.402973             3  1
# 1  0.410876      0.00      3     1.0  0.600  33.983679             5  1
# 2  0.969789      0.25      3     1.0  0.064  59.425505             2  1
# 3  1.000000      0.25      3     1.0  0.200  93.704912             2  1
# 4  0.000000      0.25      3     1.0  0.400  34.384843             6  1

# %%
# MTaking lof value of rating column
df['log_rating']=df['rating'].apply(lambda x: log(x))
df.head()
# Out:
#    name  calories  protein  fat    sodium     fiber     carbo  sugars  \
# 0     0  0.181818      0.6  0.2  0.406250  0.714286  0.250000  0.4375
# 1     1  0.636364      0.4  1.0  0.046875  0.142857  0.375000  0.5625
# 2     2  0.181818      0.6  0.2  0.812500  0.642857  0.333333  0.3750
# 3     3  0.000000      0.6  0.0  0.437500  1.000000  0.375000  0.0625
# 4     4  0.545455      0.2  0.4  0.625000  0.071429  0.625000  0.5625
#
#      potass  vitamins  shelf  weight   cups     rating  manufactures  C  \
# 0  0.848943      0.25      3     1.0  0.064  68.402973             3  1
# 1  0.410876      0.00      3     1.0  0.600  33.983679             5  1
# 2  0.969789      0.25      3     1.0  0.064  59.425505             2  1
# 3  1.000000      0.25      3     1.0  0.200  93.704912             2  1
# 4  0.000000      0.25      3     1.0  0.400  34.384843             6  1
#
#    log_rating
# 0    4.225416
# 1    3.525880
# 2    4.084724
# 3    4.540151
# 4    3.537616

# %%
# Dropping the rating column
df.drop('rating', axis=1,inplace=True)
df.head()
# Out:
#    name  calories  protein  fat    sodium     fiber     carbo  sugars  \
# 0     0  0.181818      0.6  0.2  0.406250  0.714286  0.250000  0.4375
# 1     1  0.636364      0.4  1.0  0.046875  0.142857  0.375000  0.5625
# 2     2  0.181818      0.6  0.2  0.812500  0.642857  0.333333  0.3750
# 3     3  0.000000      0.6  0.0  0.437500  1.000000  0.375000  0.0625
# 4     4  0.545455      0.2  0.4  0.625000  0.071429  0.625000  0.5625
#
#      potass  vitamins  shelf  weight   cups  manufactures  C  log_rating
# 0  0.848943      0.25      3     1.0  0.064             3  1    4.225416
# 1  0.410876      0.00      3     1.0  0.600             5  1    3.525880
# 2  0.969789      0.25      3     1.0  0.064             2  1    4.084724
# 3  1.000000      0.25      3     1.0  0.200             2  1    4.540151
# 4  0.000000      0.25      3     1.0  0.400             6  1    3.537616

# %%
# Plotting the histogram plot for all numeric and boolean columns
df.hist(figsize = (20, 20), bins = 10)
plt.tight_layout()

# %% [markdown]
# ### Question 3: Extract the rating as your target variable ‘y’ and all numerical parameters as your predictors ‘x’. Separate 25% of your data as test set.

# %%
# Splitting the data
X = df.drop('log_rating', axis=1)
y = df['log_rating']
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %%
# Importing Linear Regression model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %% [markdown]
# ### Question 4: Fit a linear regression module and measure the mean squared error on test dataset.[ Hint: Explore linear models and metrics section of sklearn documentation]

# %%
# Fitting the model to the training data
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Trainig score data
lr.score(X_train,y_train)
# Out:
# 0.9718030891319045

# %%
# making the predictions
y_preds=lr.predict(X_test)

# %%
# Checking the predictions
y_preds
# Out:
# array([3.13656741, 3.56506855, 3.68222968, 3.53165563, 3.41720085,
#        3.91588225, 3.45304715, 4.03969919, 3.31978953, 4.01687342,
#        3.35558076, 3.38862037, 3.41663442, 3.53225867, 4.17217967,
#        3.84448508, 3.62313948, 4.41483613, 3.36953396, 3.34688222])

# %%
# Checking the score of test data
lr.score(X_test,y_test)
# Out:
# 0.9407561340989073

# %%
# Finding mean_absolute_error 
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(mean_absolute_error(y_test, y_preds))
# Out:
# 0.06377997108265276

# %%
# Finding mean_squared_error 
print(mean_squared_error(y_test, y_preds))
# Out:
# 0.006887551942969705

# %%
# Getting the mean_absolute_error in true rating values
np.exp(0.05369946746421914)
# Out:
# 1.0551674423519237

# %%
# Getting the mean_squared_error in true ratings value
np.exp(0.0040189893050319395)
# Out:
# 1.0040270762727317
